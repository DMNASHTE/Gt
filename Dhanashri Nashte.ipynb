# %% [markdown]
# Q1 :Python code is  compiled or  interpreted ?
#
# 1.Python code is both compiled and interpreted
# 2.Python code is neither compiled and nor interpreted
# 3.Python code is only compiled
# 4.Python code is only Interpreted
#
#
# Answer:-Python code is both compiled and interpreter

# %% [markdown]
# Q2:-
# Answer: It indicates a private of a class

# %% [markdown]
# Q3:-
# answer:You don't have covid ,test says you have covid

# %% [markdown]
# Q4:-
# answer-84

# %% [markdown]
# Q5-
# answer- Option 1="*"

# %%
#Q1
s=input("Enter a your name :")
for i in range(len(s)):
    if (i%2==0):
        print(s[i])
# Out:
# Enter a your name :DHANASHRI
# D
# A
# A
# H
# I

# %%
import numpy as np

# %%
# Q2

number=[12,75,150,180,145,525,50]
s=np.array(number)
for i in range(len(s)):
    if (s[i]%5==0):
        print("")
    if (s[i]>150):
        continue
    if (s[i]>500):
        break
    print(s[i])
# Out:
# 12
#
# 75
#
# 150
#
#
# 145
#
#
# 50

# %%
#Q3:
n=[1,2,3,4,5,6,7]
a=np.array(n)
print(a*a)
# Out:
# [ 1  4  9 16 25 36 49]

# %%
day=["Sun","Mon=","Tues","Wed","Thur","Fri","sat"]
number=[1,2,3,4,5,6,7]
d={i:j for i,j in zip(day,number)}
d
# Out:
# {'Sun': 1, 'Mon=': 2, 'Tues': 3, 'Wed': 4, 'Thur': 5, 'Fri': 6, 'sat': 7}

# %%
Q5: We have a 52 cards in we are taken a two cards from 52 cards and the posibitily of getting 2 cards from the cards
       p=7/16

# %%
# Q6
 it overiding the value of function which we give in a function  But in a class we given another value but 
 then we in object we access another value but it also run 
 It is called the overridding
# It works over a parent class means child class works both the child and parent class 
#but parent class doesnot access the child class

# %%
def add(a,b=0):
    print(a+b)

# %%
s=add(13,14)  # it overiding the value of function which we give in a function  But in a class we given another value but 
              #then we in object we access another value but it also run 
              #It is called the overridding
# Out:
# 27

# %%
#Q7
s=int(input("Enter a number:")) 
if (s%5==0 + s%7==0):
    print("Number is divisible by both 5 and 7")
else:
        print("Number is not divisible by both 5 and 7")
# Out:
# Enter a number:12
# Number is not divisible by both 5 and 7

# %% [markdown]
# Q8: Types of distribution
#     pribability distribustion: Pdf,CDG,Pmf
#     we are distributed in according to  we use joint probabily, marginal probability,conditional probability'
#     statistical :Inferential statistics
#     population realted questions are solve in this
#     we use a mean ,median, mode.
#     calculate the standard deviation ,variance.
#     Hypothesis there are two types of hypothesis
#     null hypothesis,alternative hypothesis.
#     skewneess positive ,negative skewness,normal

# %%
#Q9: Central limit theorm
 1)mean :Avearge of the numbers is called mean
 2)Median: The middle number is in list is called median
 3)mode:The frequency of number is greater is called mode
    if mean, median ,mode is same central limit theorem

# %%
#Q 10:  
def numbers(a,b):
    print(a+b)
    print(a-b)
    print(a*b)

# %%
s=numbers(12,24)
# Out:
# 36
# -12
# 288

# %%
#Q3: Q1
import pandas as pd
import matplotlib.pyplot as plt

# %%
s=pd.read_csv("supermarket_sales - Sheet1.csv")
s
# Out:
#       Invoice ID Branch       City Customer type  Gender  \
# 0    750-67-8428      A     Yangon        Member  Female
# 1    226-31-3081      C  Naypyitaw        Normal  Female
# 2    631-41-3108      A     Yangon        Normal    Male
# 3    123-19-1176      A     Yangon        Member    Male
# 4    373-73-7910      A     Yangon        Normal    Male
# ..           ...    ...        ...           ...     ...
# 995  233-67-5758      C  Naypyitaw        Normal    Male
# 996  303-96-2227      B   Mandalay        Normal  Female
# 997  727-02-1313      A     Yangon        Member    Male
# 998  347-56-2442      A     Yangon        Normal    Male
# 999  849-09-3807      A     Yangon        Member  Female
#
#                Product line  Unit price  Quantity   Tax 5%      Total  \
# 0         Health and beauty       74.69         7  26.1415   548.9715
# 1    Electronic accessories       15.28         5   3.8200    80.2200
# ...

# %%
#Q3 4.
s['Gender'].value_counts()
# Out:
# Female    501
# Male      499
# Name: Gender, dtype: int64

# %%
s.index
# Out:
# RangeIndex(start=0, stop=1000, step=1)

# %%
s.shape
# Out:
# (7,)

# %%
#Q3:1
s.drop(['Invoice ID','Time','Date'],axis=1)
# Out:
#     Branch       City Customer type  Gender            Product line  \
# 0        A     Yangon        Member  Female       Health and beauty
# 1        C  Naypyitaw        Normal  Female  Electronic accessories
# 2        A     Yangon        Normal    Male      Home and lifestyle
# 3        A     Yangon        Member    Male       Health and beauty
# 4        A     Yangon        Normal    Male       Sports and travel
# ..     ...        ...           ...     ...                     ...
# 995      C  Naypyitaw        Normal    Male       Health and beauty
# 996      B   Mandalay        Normal  Female      Home and lifestyle
# 997      A     Yangon        Member    Male      Food and beverages
# 998      A     Yangon        Normal    Male      Home and lifestyle
# 999      A     Yangon        Member  Female     Fashion accessories
#
#      Unit price  Quantity   Tax 5%      Total      Payment    cogs  \
# 0         74.69         7  26.1415   548.9715      Ewallet  522.83
# ...

# %%
s.describe()
# Out:
#         Unit price     Quantity       Tax 5%        Total        cogs  \
# count  1000.000000  1000.000000  1000.000000  1000.000000  1000.00000
# mean     55.672130     5.510000    15.379369   322.966749   307.58738
# std      26.494628     2.923431    11.708825   245.885335   234.17651
# min      10.080000     1.000000     0.508500    10.678500    10.17000
# 25%      32.875000     3.000000     5.924875   124.422375   118.49750
# 50%      55.230000     5.000000    12.088000   253.848000   241.76000
# 75%      77.935000     8.000000    22.445250   471.350250   448.90500
# max      99.960000    10.000000    49.650000  1042.650000   993.00000
#
#        gross margin percentage  gross income      Rating
# count             1.000000e+03   1000.000000  1000.00000
# mean              4.761905e+00     15.379369     6.97270
# std               6.131498e-14     11.708825     1.71858
# min               4.761905e+00      0.508500     4.00000
# ...

# %%
Q3:4
    Yes Data set has outliers
    we calculate a outliar using a Q1=25% and Q3=75%

# %%
Q3:5
    Tax 5% and Rating are strongly related
